# %%
import torch
import pickle
from batteryml import BatteryData

# %%
with open('/Users/sushankmishra/Desktop/MTP_Materials/BatteryML-main/cache/battery_cache_0c1290e76cd5c2c2872f3dd25e84b315.pkl','rb') as f:
    data = pickle.load(f)
    print(type(data))
    print(dir(data))

# %%
type(data)
for i in data['raw_data']:
    print(i)
data['dataset']
